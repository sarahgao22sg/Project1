# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd

import scipy.stats as st
import numpy as np
from citipy import citipy
import time
import json
from pprint import pprint

# %%
# Request API response and store in variable called "response"
url_ju_av = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tavg-1-6-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"

url_jul_av = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tavg-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_aug_av = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tavg-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_jun_max  ="https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tmax-1-6-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_jul_max = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tmax-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_aug_max = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-tmax-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_jun_DR =  "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-pdsi-1-6-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_jul_DR =  "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-pdsi-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_aug_DR = "https://www.ncdc.noaa.gov/cag/statewide/time-series/13-pdsi-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"

jun_ar_re = requests.get(url_ju_av)
jul_ar_re = requests.get(url_jul_av)
aug_ar_re = requests.get(url_aug_av)
jun_max_re = requests.get(url_jun_max)
jul_max_re = requests.get(url_jul_max)
aug_max_re = requests.get(url_aug_max)
jun_DR_re = requests.get(url_jun_DR)
jul_DR_re = requests.get(url_jul_DR)
aug_DR_re = requests.get(url_aug_DR )
# create new variable that contains the json output from the request
response_junA = jun_ar_re.json()
response_julA = jul_ar_re.json()
response_augA = aug_ar_re.json()
response_junM = jun_max_re.json()
response_julM = jul_max_re.json()
response_augM = aug_max_re.json()
response_junDR =jun_DR_re.json()
response_julDR = jul_DR_re.json()
response_augDR = aug_DR_re.json()
print(type(response_junA))
# Out:
# <class 'dict'>

# %% [markdown]
# ## creating dataframe for average temp in IOWA ( July -Aug)

# %%
datajunA = response_junA ["data"]
JA_df = pd.DataFrame.from_dict(datajunA , orient="index")
JA_df = JA_df .rename(columns={"value": "Jun mean Temp"})
JA_df.reset_index(drop=True, inplace=True)

dataJulA = response_julA ["data"]
JulA_df = pd.DataFrame.from_dict(dataJulA , orient="index")
JulA_df = JulA_df .rename(columns={"value": "Jul mean Temp"})
JulA_df.reset_index(drop=True, inplace=True)

dataAugA = response_augA["data"]
AugA_df = pd.DataFrame.from_dict(dataAugA , orient="index")
AugA_df = AugA_df .rename(columns={"value": "Aug mean Temp"})
AugA_df.reset_index(drop=True, inplace=True)


Jun_Jul_ave = pd.merge(JA_df, JulA_df, left_index=True, right_index=True)
Jun_Jul_ave

Jun_Jul_Aug_ave = pd.merge(Jun_Jul_ave, AugA_df,  left_index=True, right_index=True)
Jun_Jul_Aug_ave

Iowa_meanTemp = Jun_Jul_Aug_ave.drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Iowa_meanTemp.head()
# Out:
#   Jun mean Temp Jul mean Temp Aug mean Temp
# 0          69.6          76.7          73.3
# 1          70.2          73.3          69.6
# 2          64.5          74.1          70.0
# 3          69.6          77.2          78.1
# 4          70.5          72.2          73.4

# %% [markdown]
# ## creating dataframe for max temp in Iowa (Jun-Aug)

# %%
datajulM = response_junM ["data"]
JM_df = pd.DataFrame.from_dict(datajulM , orient="index")
JM_df = JM_df .rename(columns={"value": "Jun Max Temp"})
JM_df.reset_index(drop=True, inplace=True)

dataJulM = response_julM ["data"]
JulM_df = pd.DataFrame.from_dict(dataJulM , orient="index")
JulM_df = JulM_df .rename(columns={"value": "Jul MaxTemp"})
JulM_df.reset_index(drop=True, inplace=True)

dataAugM = response_augM ["data"]
AugM_df = pd.DataFrame.from_dict(dataAugM , orient="index")
AugM_df = AugM_df .rename(columns={"value": "Aug MaxTemp"})
AugM_df.reset_index(drop=True, inplace=True)

Jun_Jul_max = pd.merge(JM_df, JulM_df, left_index=True, right_index=True)


Jun_Jul_Aug_max = pd.merge(Jun_Jul_max, AugM_df,  left_index=True, right_index=True)

Iowa_maxTemp = Jun_Jul_Aug_max.drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Iowa_maxTemp.head()
# Out:
#   Jun Max Temp Jul MaxTemp Aug MaxTemp
# 0         81.5        88.8        84.3
# 1         82.0        83.0        80.1
# 2         75.7        84.8        80.1
# 3         80.5        88.8        90.4
# 4         81.3        83.9        86.0

# %%
Iowa_mean_max = pd.merge(Iowa_meanTemp, Iowa_maxTemp,  left_index=True, right_index=True)
Iowa_mean_max.head()
# Out:
#   Jun mean Temp Jul mean Temp Aug mean Temp Jun Max Temp Jul MaxTemp  \
# 0          69.6          76.7          73.3         81.5        88.8
# 1          70.2          73.3          69.6         82.0        83.0
# 2          64.5          74.1          70.0         75.7        84.8
# 3          69.6          77.2          78.1         80.5        88.8
# 4          70.5          72.2          73.4         81.3        83.9
#
#   Aug MaxTemp
# 0        84.3
# 1        80.1
# 2        80.1
# 3        90.4
# 4        86.0

# %% [markdown]
# ## creating dataframe for drought in Iowa (Jun-Aug)

# %%
datajunDR = response_junDR  ["data"]
JD_df = pd.DataFrame.from_dict(datajunDR , orient="index")
JD_df = JD_df .rename(columns={"value": "Jun Drought Severity"})
JD_df.reset_index(drop=True, inplace=True)

dataJulD = response_julDR  ["data"]
JulD_df = pd.DataFrame.from_dict(dataJulD , orient="index")
JulD_df = JulD_df .rename(columns={"value": "Jul Drought Severity"})
JulD_df.reset_index(drop=True, inplace=True)


dataAugDR = response_augDR ["data"]
AugD_df = pd.DataFrame.from_dict(dataAugDR, orient="index")
AugD_df = AugD_df .rename(columns={"value": "Aug Drought Severity"})
AugD_df.reset_index(drop=True, inplace=True)

Jun_Jul_DR = pd.merge(JD_df, JulD_df, left_index=True, right_index=True)


Jun_Jul_Aug_DR = pd.merge(Jun_Jul_DR, AugD_df,  left_index=True, right_index=True)

Iowa_DR = Jun_Jul_Aug_DR .drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Iowa_DR.head()
# Out:
#   Jun Drought Severity Jul Drought Severity Aug Drought Severity
# 0                -1.15                -1.63                 1.36
# 1                 0.30                 0.88                 1.58
# 2                 2.44                 3.29                 3.49
# 3                 4.60                 3.61                 2.30
# 4                 4.14                 4.00                 2.49

# %% [markdown]
# ## merging Dataframes

# %%
Iowa_weather = pd.merge(Iowa_mean_max, Iowa_DR,  left_index=True, right_index=True)
Iowa_weather.head()
# Out:
#   Jun mean Temp Jul mean Temp Aug mean Temp Jun Max Temp Jul MaxTemp  \
# 0          69.6          76.7          73.3         81.5        88.8
# 1          70.2          73.3          69.6         82.0        83.0
# 2          64.5          74.1          70.0         75.7        84.8
# 3          69.6          77.2          78.1         80.5        88.8
# 4          70.5          72.2          73.4         81.3        83.9
#
#   Aug MaxTemp Jun Drought Severity Jul Drought Severity Aug Drought Severity
# 0        84.3                -1.15                -1.63                 1.36
# 1        80.1                 0.30                 0.88                 1.58
# 2        80.1                 2.44                 3.29                 3.49
# 3        90.4                 4.60                 3.61                 2.30
# 4        86.0                 4.14                 4.00                 2.49

# %% [markdown]
# ## adding year as a new column to the dataframe

# %%
Date = [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 
       2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

Iowa_weather.insert(0, 'Year', Date)
Iowa_weather
#Iowa_weather_year = Iowa_weather .drop(columns=['date'])
Iowa_weather_year = Iowa_weather

Iowa_weather_year.to_csv("output_data/Iowa_weather.csv", index = False)
Iowa_weather_year.head()
# Out:
#    Year Jun mean Temp Jul mean Temp Aug mean Temp Jun Max Temp Jul MaxTemp  \
# 0  1980          69.6          76.7          73.3         81.5        88.8
# 1  1981          70.2          73.3          69.6         82.0        83.0
# 2  1982          64.5          74.1          70.0         75.7        84.8
# 3  1983          69.6          77.2          78.1         80.5        88.8
# 4  1984          70.5          72.2          73.4         81.3        83.9
#
#   Aug MaxTemp Jun Drought Severity Jul Drought Severity Aug Drought Severity
# 0        84.3                -1.15                -1.63                 1.36
# 1        80.1                 0.30                 0.88                 1.58
# 2        80.1                 2.44                 3.29                 3.49
# 3        90.4                 4.60                 3.61                 2.30
# 4        86.0                 4.14                 4.00                 2.49

# %% [markdown]
# ## calling csv file data from USDA and merging to weather dataframe

# %%
Iowa_path = "output_data/IOWA_corn_soyben_yield_Aug.csv"
Iowa_corn_soy_yield = pd.read_csv(Iowa_path)
Iowa_corn_soy_yield.head()
# Out:
#    Year  August Corn yield  August soybean yield
# 0  1980             7.2684                 2.4228
# 1  1981             8.4125                 2.6920
# 2  1982             8.2106                 2.5574
# 3  1983             7.6722                 2.5574
# 4  1984             8.2106                 2.5574

# %%
Iowa_weather_yield = pd.merge(Iowa_weather_year, Iowa_corn_soy_yield, on="Year")
Iowa_weather_yield.tail(10)
Iowa_weather_yield.dtypes
# Out:
# Year                       int64
# Jun mean Temp             object
# Jul mean Temp             object
# Aug mean Temp             object
# Jun Max Temp              object
# Jul MaxTemp               object
# Aug MaxTemp               object
# Jun Drought Severity      object
# Jul Drought Severity      object
# Aug Drought Severity      object
# August Corn yield        float64
# August soybean yield     float64
# dtype: object

# %% [markdown]
# ## Converting object to float

# %%
Iowa_weather_yield['Jun mean Temp'] = Iowa_weather_yield['Jun mean Temp'].astype(str).astype(float)
Iowa_weather_yield['Jul mean Temp'] = Iowa_weather_yield['Jul mean Temp'].astype(str).astype(float)
Iowa_weather_yield['Aug mean Temp'] = Iowa_weather_yield['Aug mean Temp'].astype(str).astype(float)
Iowa_weather_yield['Jun Max Temp'] = Iowa_weather_yield['Jun Max Temp'].astype(str).astype(float)
Iowa_weather_yield['Jul MaxTemp'] = Iowa_weather_yield['Jul MaxTemp'].astype(str).astype(float)
Iowa_weather_yield['Aug MaxTemp'] = Iowa_weather_yield['Aug MaxTemp'].astype(str).astype(float)
Iowa_weather_yield['Jun Drought Severity'] = Iowa_weather_yield['Jun Drought Severity'].astype(str).astype(float)
Iowa_weather_yield['Jul Drought Severity'] = Iowa_weather_yield['Jul Drought Severity'].astype(str).astype(float)
Iowa_weather_yield['Aug Drought Severity'] = Iowa_weather_yield['Aug Drought Severity'].astype(str).astype(float)

# %%
Iowa_weather_yield.dtypes
# Out:
# Year                       int64
# Jun mean Temp            float64
# Jul mean Temp            float64
# Aug mean Temp            float64
# Jun Max Temp             float64
# Jul MaxTemp              float64
# Aug MaxTemp              float64
# Jun Drought Severity     float64
# Jul Drought Severity     float64
# Aug Drought Severity     float64
# August Corn yield        float64
# August soybean yield     float64
# dtype: object

# %%
Iowa_weather_yield.head()
# Out:
#    Year  Jun mean Temp  Jul mean Temp  Aug mean Temp  Jun Max Temp  \
# 0  1980           69.6           76.7           73.3          81.5
# 1  1981           70.2           73.3           69.6          82.0
# 2  1982           64.5           74.1           70.0          75.7
# 3  1983           69.6           77.2           78.1          80.5
# 4  1984           70.5           72.2           73.4          81.3
#
#    Jul MaxTemp  Aug MaxTemp  Jun Drought Severity  Jul Drought Severity  \
# 0         88.8         84.3                 -1.15                 -1.63
# 1         83.0         80.1                  0.30                  0.88
# 2         84.8         80.1                  2.44                  3.29
# 3         88.8         90.4                  4.60                  3.61
# 4         83.9         86.0                  4.14                  4.00
#
#    Aug Drought Severity  August Corn yield  August soybean yield
# ...

# %%
## saving Dataframe
Iowa_weather_year.to_csv("output_data/Iowa_weather_year.csv", index = False)

# %% [markdown]
# ## creating graphs for august Yield (corn harvest month) vs August averate temp, max temp, and drought severity

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August Corn yield']
y2_axis= Iowa_weather_yield['Aug Drought Severity']


fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")

ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("August Yield",fontsize=14)
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))

ax2=ax.twinx()
#ax2=corn_y.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Drought Severity")
ax2.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
#severity.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()
plt.title("August Corn Yield vs Drought Severity", fontsize=14)

plt.legend(loc="upper left")
plt.savefig("output_data/Corn-Aug-Drought.png")
plt.show()

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August Corn yield']
y2_axis= Iowa_weather_yield['Aug mean Temp']




fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("August Yield",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Average Temp")
ax2.set_ylabel("Average Temp (F)",fontsize=14)
plt.tight_layout()

plt.title("August Corn Yield vs Average Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.savefig("output_data/Corn-Aug-averaT.png")
plt.show()

# %% [markdown]
# ## creating graphs for soybean august yield vs average temp, max temp, and drought severity

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August Corn yield']
y2_axis= Iowa_weather_yield['Aug MaxTemp']




fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Aug Max temp (F)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label= "Max Temp")
ax2.set_ylabel("Max Temp (F)",fontsize=14)
plt.tight_layout()
plt.title("August Corn Yield vs Max Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.savefig("output_data/Corn-Aug-MaxT.png")
plt.show()

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August soybean yield ']

y2_axis= Iowa_weather_yield['Aug MaxTemp']



fig, ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Aug Max temp (F)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Max Temp")
ax2.set_ylabel("Max Temp (F)",fontsize=14)
plt.tight_layout()
plt.title("August Soybean Yield vs Max Temperature", fontsize=14)
plt.legend(loc="upper left")


plt.show()

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August soybean yield ']

y2_axis= Iowa_weather_yield['Aug Drought Severity']



fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Aug Max temp (F)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Drought Severety")
ax2.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()
plt.title("August Soybean Yield vs Drough Severity", fontsize=14)
plt.legend(loc="upper left")

plt.savefig("output_data/Soy-Aug-Drought.png")
plt.show()

# %%
x_axis = Iowa_weather_yield['Year']
y_axis=  Iowa_weather_yield['August soybean yield ']
y2_axis= Iowa_weather_yield['Aug mean Temp']




fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("August Yield",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Average Temp")
ax2.set_ylabel("Average Temp (F)",fontsize=14)
plt.tight_layout()

plt.title("August Soybean Yield vs Average Temperature", fontsize=14)
plt.legend(loc="upper left")

plt.savefig("output_data/Soy-Aug-AveT.png")
plt.show()

# %%
Iowa_weather_yield.head()
# Out:
#    Year  Jun mean Temp  Jul mean Temp  Aug mean Temp  Jun Max Temp  \
# 0  1980           69.6           76.7           73.3          81.5
# 1  1981           70.2           73.3           69.6          82.0
# 2  1982           64.5           74.1           70.0          75.7
# 3  1983           69.6           77.2           78.1          80.5
# 4  1984           70.5           72.2           73.4          81.3
#
#    Jul MaxTemp  Aug MaxTemp  Jun Drought Severity  Jul Drought Severity  \
# 0         88.8         84.3                 -1.15                 -1.63
# 1         83.0         80.1                  0.30                  0.88
# 2         84.8         80.1                  2.44                  3.29
# 3         88.8         90.4                  4.60                  3.61
# 4         83.9         86.0                  4.14                  4.00
#
#    Aug Drought Severity  August Corn yield  August soybean yield
# ...

# %% [markdown]
# ## Calculating the mean of the season weather data and adding the columns to the dataframe

# %%
iowa_season_Temp = Iowa_weather_yield[['Jun mean Temp', 'Jul mean Temp', 'Aug mean Temp']]
mean_season_temp= iowa_season_Temp.mean(axis=1)
Iowa_weather_yield.insert(1, "Seasonal_temp", mean_season_temp)

# %%
Iowa_weather_yield.head()
# Out:
#    Year  Seasonal_temp  Jun mean Temp  Jul mean Temp  Aug mean Temp  \
# 0  1980      73.200000           69.6           76.7           73.3
# 1  1981      71.033333           70.2           73.3           69.6
# 2  1982      69.533333           64.5           74.1           70.0
# 3  1983      74.966667           69.6           77.2           78.1
# 4  1984      72.033333           70.5           72.2           73.4
#
#    Jun Max Temp  Jul MaxTemp  Aug MaxTemp  Jun Drought Severity  \
# 0          81.5         88.8         84.3                 -1.15
# 1          82.0         83.0         80.1                  0.30
# 2          75.7         84.8         80.1                  2.44
# 3          80.5         88.8         90.4                  4.60
# 4          81.3         83.9         86.0                  4.14
#
#    Jul Drought Severity  Aug Drought Severity  August Corn yield  \
# 0                 -1.63                  1.36             7.2684
# ...

# %%
iowa_season_Temp = Iowa_weather_yield[['Jun Max Temp', 'Jul MaxTemp', 'Aug MaxTemp']]
mean_season_temp= iowa_season_Temp.mean(axis=1)
new_iowa_ave = Iowa_weather_yield.insert(1, "Seasonal_Max", mean_season_temp)

# %%
iowa_season_Temp = Iowa_weather_yield[['Jun Drought Severity', 'Jul Drought Severity', 'Aug Drought Severity']]
mean_season_temp= iowa_season_Temp.mean(axis=1)
Iowa_weather_yield.insert(1, "Seasonal_Drought", mean_season_temp)

# %%
Iowa_weather_yield.head()
# Out:
#    Year  Seasonal_Drought  Seasonal_Max  Seasonal_temp  Jun mean Temp  \
# 0  1980         -0.473333     84.866667      73.200000           69.6
# 1  1981          0.920000     81.700000      71.033333           70.2
# 2  1982          3.073333     80.200000      69.533333           64.5
# 3  1983          3.503333     86.566667      74.966667           69.6
# 4  1984          3.543333     83.733333      72.033333           70.5
#
#    Jul mean Temp  Aug mean Temp  Jun Max Temp  Jul MaxTemp  Aug MaxTemp  \
# 0           76.7           73.3          81.5         88.8         84.3
# 1           73.3           69.6          82.0         83.0         80.1
# 2           74.1           70.0          75.7         84.8         80.1
# 3           77.2           78.1          80.5         88.8         90.4
# 4           72.2           73.4          81.3         83.9         86.0
#
#    Jun Drought Severity  Jul Drought Severity  Aug Drought Severity  \
# ...

# %%
New_weather_yield = Iowa_weather_yield

# %%
New_weather_yield.head()
# Out:
#    Year  Seasonal_Drought  Seasonal_Max  Seasonal_temp  Jun mean Temp  \
# 0  1980         -0.473333     84.866667      73.200000           69.6
# 1  1981          0.920000     81.700000      71.033333           70.2
# 2  1982          3.073333     80.200000      69.533333           64.5
# 3  1983          3.503333     86.566667      74.966667           69.6
# 4  1984          3.543333     83.733333      72.033333           70.5
#
#    Jul mean Temp  Aug mean Temp  Jun Max Temp  Jul MaxTemp  Aug MaxTemp  \
# 0           76.7           73.3          81.5         88.8         84.3
# 1           73.3           69.6          82.0         83.0         80.1
# 2           74.1           70.0          75.7         84.8         80.1
# 3           77.2           78.1          80.5         88.8         90.4
# 4           72.2           73.4          81.3         83.9         86.0
#
#    Jun Drought Severity  Jul Drought Severity  Aug Drought Severity  \
# ...

# %%
## saving dataframe
New_weather_yield.to_csv("output_data/New_Iowa_weather_year.csv", index = False)

# %% [markdown]
# ## calling csv file with season yield of corn and soybean and merging to dataframe

# %%
CS_season_path = "output_data/Corn-Soy-seasonal_yield.csv"
CS_seasonal_yield = pd.read_csv(CS_season_path)
CS_seasonal_yield.head()
# Out:
#    Year  Season_corn_yield  Season_soybean_Yield
# 0  1980             7.4030               2.59105
# 1  1981             8.4125               2.69200
# 2  1982             8.0760               2.45645
# 3  1983             5.8551               2.35550
# 4  1984             7.5376               2.11995

# %%
Iowa_last_weather = pd.merge(New_weather_yield, CS_seasonal_yield, on="Year")
Iowa_last_weather.to_csv("output_data/Iowa_last_weather.csv", index = False)
Iowa_last_weather
# Out:
#     Year  Seasonal_Drought  Seasonal_Max  Seasonal_temp  Jun mean Temp  \
# 0   1980         -0.473333     84.866667      73.200000           69.6
# 1   1981          0.920000     81.700000      71.033333           70.2
# 2   1982          3.073333     80.200000      69.533333           64.5
# 3   1983          3.503333     86.566667      74.966667           69.6
# 4   1984          3.543333     83.733333      72.033333           70.5
# 5   1985         -1.063333     80.800000      69.033333           66.5
# 6   1986          2.156667     81.833333      71.233333           71.4
# 7   1987          0.096667     84.066667      73.066667           73.0
# 8   1988         -3.946667     88.266667      75.033333           73.8
# 9   1989         -5.133333     82.633333      71.300000           67.7
# 10  1990          3.270000     81.466667      71.433333           70.3
# 11  1991          1.796667     83.566667      72.733333           73.0
# ...

# %% [markdown]
# # creating graphs of corn season yield vs seasonal average temp, max temp, and drought severity

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_corn_yield']
y2_axis= Iowa_last_weather['Seasonal_Drought']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Season Drougth")
ax2.set_ylabel( "Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()

plt.title("Corn Season Yield vs Seasonal Drought", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Corn_season_drought.png")
plt.show()

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_corn_yield']
y2_axis= Iowa_last_weather['Seasonal_Max']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Average Temp")
ax2.set_ylabel( "Season Max Temp (F)",fontsize=14)


plt.title("Corn Season Yield vs Seasonal Max Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Corn_season_Max.png")
plt.show()

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_corn_yield']
y2_axis= Iowa_last_weather['Seasonal_temp']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Max Temp")
ax2.set_ylabel( "Season Average Temp (F)",fontsize=14)
plt.tight_layout()

plt.title("Corn Season Yield vs Seasonal Average Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Corn_season_ave.png")
plt.show()

# %% [markdown]
# ## Creating graphs for soybean season yield vs seasonal average temp, max temp, and drought severity

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_soybean_Yield']
y2_axis= Iowa_last_weather['Seasonal_Max']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Max Temp")
ax2.set_ylabel( "Season Max Temp (F)",fontsize=14)
plt.tight_layout()

plt.title("Soybean Season Yield vs Seasonal Max Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Soybean_season_Max.png")
plt.show()

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_soybean_Yield']
y2_axis= Iowa_last_weather['Seasonal_Drought']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Seasonal Drought")
ax2.set_ylabel( "Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()

plt.title("Soybean Season Yield vs Seasonal Drought", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Soybean_season_drought.png")
plt.show()

# %%
x_axis = Iowa_last_weather['Year']
y_axis=  Iowa_last_weather['Season_soybean_Yield']
y2_axis= Iowa_last_weather['Seasonal_temp']

fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))
ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Yield (Tons/hectares)",fontsize=14)

ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Average Temp")
ax2.set_ylabel( "Season Average Temp (F)",fontsize=14)
plt.tight_layout()

plt.title("Soybean Season Yield vs Seasonal Average Temperature", fontsize=14)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("output_data/Soybean_season_ave.png")
plt.show()

# %% [markdown]
# ## Calling JSON of California Weather rice season

# %%
url_calD_Jul= "https://www.ncdc.noaa.gov/cag/statewide/time-series/4-pdsi-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"

url_calD_Aug= "https://www.ncdc.noaa.gov/cag/statewide/time-series/4-pdsi-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"

url_calD_Sep= "https://www.ncdc.noaa.gov/cag/statewide/time-series/4-pdsi-1-9-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_calA_Jul="https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tavg-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_calA_Aug= "https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tavg-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_calA_Sep ="https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tavg-1-9-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_calM_Jul ="https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tmax-1-7-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"
url_calM_Aug = "https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tmax-1-8-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"

url_calM_Sep="https://www.ncdc.noaa.gov/cag/statewide/time-series/4-tmax-1-9-1980-2020.json?base_prd=true&begbaseyear=1901&endbaseyear=2000"


jul_dr_re = requests.get(url_calD_Jul)
aug_dr_re = requests.get(url_calD_Aug)
sep_dr_re = requests.get(url_calD_Sep)
jul_av_re = requests.get(url_calA_Jul)
aug_av_re = requests.get(url_calA_Aug)
sep_av_re = requests.get(url_calA_Sep)
jul_M_re = requests.get(url_calM_Jul)
aug_M_re = requests.get(url_calM_Aug)
sep_M_re = requests.get(url_calM_Sep )
# create new variable that contains the json output from the request
response_julDC = jul_dr_re.json()
response_augDC = aug_dr_re.json()
response_sepDC = sep_dr_re.json()
response_julAC = jul_av_re.json()
response_augAC = aug_av_re.json()
response_sepAC = sep_av_re.json()
response_julMC =jul_M_re.json()
response_augMC = aug_M_re.json()
response_sepMC = sep_M_re.json()
print(type(response_sepMC))
# Out:
# <class 'dict'>

# %% [markdown]
# ## start creating dataframe

# %%
C_julD = response_julDC ["data"]
CJulD_df = pd.DataFrame.from_dict(C_julD, orient="index")
CJulD_df = CJulD_df .rename(columns={"value": "Jul Drought"})
CJulD_df.reset_index(drop=True, inplace=True)

C_augD = response_augDC ["data"]
CAugD_df = pd.DataFrame.from_dict(C_augD , orient="index")
CAugD_df = CAugD_df .rename(columns={"value": "Aug Drought"})
CAugD_df.reset_index(drop=True, inplace=True)

C_sepD = response_sepDC ["data"]
CSepD_df = pd.DataFrame.from_dict(C_augD , orient="index")
CSepD_df = CSepD_df .rename(columns={"value": "Sep Drought"})
CSepD_df.reset_index(drop=True, inplace=True)


JA_D = pd.merge(CJulD_df, CAugD_df, left_index=True, right_index=True)
JA_D

JAS_D = pd.merge(JA_D, CSepD_df,  left_index=True, right_index=True)
JAS_D

Cali_drought = JAS_D.drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Cali_drought.head()
# Out:
#   Jul Drought Aug Drought Sep Drought
# 0        2.38       -0.16       -0.16
# 1       -2.49       -2.64       -2.64
# 2        3.09        3.07        3.07
# 3        5.82        6.45        6.45
# 4        0.16        0.50        0.50

# %%
C_julA = response_julAC ["data"]
CJulA_df = pd.DataFrame.from_dict(C_julA, orient="index")
CJulA_df = CJulA_df .rename(columns={"value": "Jul_ave_temp"})
CJulA_df.reset_index(drop=True, inplace=True)

C_augA = response_augAC ["data"]
CAugA_df = pd.DataFrame.from_dict(C_augA , orient="index")
CAugA_df = CAugA_df .rename(columns={"value": "Aug_ave_temp"})
CAugA_df.reset_index(drop=True, inplace=True)

C_sepA = response_sepAC ["data"]
CSepA_df = pd.DataFrame.from_dict(C_sepA , orient="index")
CSepA_df = CSepA_df .rename(columns={"value": "Sep_ave_temp"})
CSepA_df.reset_index(drop=True, inplace=True)


JA_A = pd.merge(CJulA_df, CAugA_df, left_index=True, right_index=True)
JA_A

JAS_A = pd.merge(JA_A, CSepA_df,  left_index=True, right_index=True)
JAS_A

Cali_Ave_Temp = JAS_A.drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Cali_Ave_Temp.head()
# Out:
#   Jul_ave_temp Aug_ave_temp Sep_ave_temp
# 0         75.4         73.0         68.6
# 1         75.5         75.8         70.4
# 2         73.1         73.9         67.1
# 3         71.9         73.7         71.0
# 4         77.0         74.9         72.2

# %%
Cali_DA= pd.merge(Cali_drought, Cali_Ave_Temp,  left_index=True, right_index=True)
Cali_DA.head()
# Out:
#   Jul Drought Aug Drought Sep Drought Jul_ave_temp Aug_ave_temp Sep_ave_temp
# 0        2.38       -0.16       -0.16         75.4         73.0         68.6
# 1       -2.49       -2.64       -2.64         75.5         75.8         70.4
# 2        3.09        3.07        3.07         73.1         73.9         67.1
# 3        5.82        6.45        6.45         71.9         73.7         71.0
# 4        0.16        0.50        0.50         77.0         74.9         72.2

# %%
C_julM = response_julMC ["data"]
CJulM_df = pd.DataFrame.from_dict(C_julM, orient="index")
CJulM_df = CJulM_df .rename(columns={"value": "Jul_Max_Temp"})
CJulM_df.reset_index(drop=True, inplace=True)

C_augM = response_augMC ["data"]
CAugM_df = pd.DataFrame.from_dict(C_augM , orient="index")
CAugM_df = CAugM_df .rename(columns={"value": "Aug_Max_Temp"})
CAugM_df.reset_index(drop=True, inplace=True)

C_sepM = response_sepMC ["data"]
CSepM_df = pd.DataFrame.from_dict(C_sepM , orient="index")
CSepM_df = CSepM_df .rename(columns={"value": "Sep_Max_temp"})
CSepM_df.reset_index(drop=True, inplace=True)


JA_M = pd.merge(CJulM_df, CAugM_df, left_index=True, right_index=True)
JA_M

JAS_M = pd.merge(JA_M, CSepM_df,  left_index=True, right_index=True)
JAS_M

Cali_Max= JAS_M.drop(columns=['anomaly_x', 'anomaly_y', 'anomaly'])
Cali_Max.head()
# Out:
#   Jul_Max_Temp Aug_Max_Temp Sep_Max_temp
# 0         90.0         87.8         83.2
# 1         91.2         91.4         84.6
# 2         87.3         88.1         79.6
# 3         86.4         86.8         84.2
# 4         91.2         89.0         86.5

# %%
Cali= pd.merge(Cali_DA, Cali_Max,  left_index=True, right_index=True)
Cali.head()
# Out:
#   Jul Drought Aug Drought Sep Drought Jul_ave_temp Aug_ave_temp Sep_ave_temp  \
# 0        2.38       -0.16       -0.16         75.4         73.0         68.6
# 1       -2.49       -2.64       -2.64         75.5         75.8         70.4
# 2        3.09        3.07        3.07         73.1         73.9         67.1
# 3        5.82        6.45        6.45         71.9         73.7         71.0
# 4        0.16        0.50        0.50         77.0         74.9         72.2
#
#   Jul_Max_Temp Aug_Max_Temp Sep_Max_temp
# 0         90.0         87.8         83.2
# 1         91.2         91.4         84.6
# 2         87.3         88.1         79.6
# 3         86.4         86.8         84.2
# 4         91.2         89.0         86.5

# %% [markdown]
# ## Adding years to dataframe

# %%
Date = [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 
       2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

Cali.insert(0, 'Year', Date)
Cali
#Iowa_weather_year = Iowa_weather .drop(columns=['date'])
Cali_weatherDAM = Cali

# %%
Cali_weatherDAM.head()
# Out:
#    Year Jul Drought Aug Drought Sep Drought Jul_ave_temp Aug_ave_temp  \
# 0  1980        2.38       -0.16       -0.16         75.4         73.0
# 1  1981       -2.49       -2.64       -2.64         75.5         75.8
# 2  1982        3.09        3.07        3.07         73.1         73.9
# 3  1983        5.82        6.45        6.45         71.9         73.7
# 4  1984        0.16        0.50        0.50         77.0         74.9
#
#   Sep_ave_temp Jul_Max_Temp Aug_Max_Temp Sep_Max_temp
# 0         68.6         90.0         87.8         83.2
# 1         70.4         91.2         91.4         84.6
# 2         67.1         87.3         88.1         79.6
# 3         71.0         86.4         86.8         84.2
# 4         72.2         91.2         89.0         86.5

# %% [markdown]
# ## Converting object to float

# %%
Cali_weatherDAM['Jul Drought'] = Cali_weatherDAM['Jul Drought'].astype(str).astype(float)
Cali_weatherDAM['Aug Drought'] = Cali_weatherDAM['Aug Drought'].astype(str).astype(float)
Cali_weatherDAM['Sep Drought'] = Cali_weatherDAM['Sep Drought'].astype(str).astype(float)
Cali_weatherDAM['Jul_ave_temp'] = Cali_weatherDAM['Jul_ave_temp'].astype(str).astype(float)
Cali_weatherDAM['Aug_ave_temp'] = Cali_weatherDAM['Aug_ave_temp'].astype(str).astype(float)
Cali_weatherDAM['Sep_ave_temp'] = Cali_weatherDAM['Sep_ave_temp'].astype(str).astype(float)
Cali_weatherDAM['Jul_Max_Temp'] = Cali_weatherDAM['Jul_Max_Temp'].astype(str).astype(float)
Cali_weatherDAM['Aug_Max_Temp'] = Cali_weatherDAM['Aug_Max_Temp'].astype(str).astype(float)
Cali_weatherDAM['Sep_Max_temp'] = Cali_weatherDAM['Sep_Max_temp'].astype(str).astype(float)

# %% [markdown]
# ## calculating seasonal average weather for california

# %%
Cali_season_drought= Cali_weatherDAM[['Jul Drought', 'Aug Drought', 'Sep Drought']]
Cali_mean_drought= iowa_season_Temp.mean(axis=1)
Cali_weatherDAM.insert(1, "Seasonal_Drought", Cali_mean_drought)

# %%
Cali_season_Temp = Cali_weatherDAM[['Jul_ave_temp', 'Aug_ave_temp', 'Sep_ave_temp']]
Cali_mean_temp= Cali_season_Temp.mean(axis=1)
Cali_weatherDAM.insert(2, "Seasonal_Temp", Cali_mean_temp)

# %%
Cali_season_max = Cali_weatherDAM[['Jul_Max_Temp', 'Aug_Max_Temp', 'Sep_Max_temp']]
Cali_mean_max= Cali_season_max.mean(axis=1)
Cali_weatherDAM.insert(3, "Seasonal_Max", Cali_mean_max)

# %%
Cali_weatherDAM.head()
# Out:
#    Year  Seasonal_Drought  Seasonal_Temp  Seasonal_Max  Jul Drought  \
# 0  1980         -0.473333      72.333333     87.000000         2.38
# 1  1981          0.920000      73.900000     89.066667        -2.49
# 2  1982          3.073333      71.366667     85.000000         3.09
# 3  1983          3.503333      72.200000     85.800000         5.82
# 4  1984          3.543333      74.700000     88.900000         0.16
#
#    Aug Drought  Sep Drought  Jul_ave_temp  Aug_ave_temp  Sep_ave_temp  \
# 0        -0.16        -0.16          75.4          73.0          68.6
# 1        -2.64        -2.64          75.5          75.8          70.4
# 2         3.07         3.07          73.1          73.9          67.1
# 3         6.45         6.45          71.9          73.7          71.0
# 4         0.50         0.50          77.0          74.9          72.2
#
#    Jul_Max_Temp  Aug_Max_Temp  Sep_Max_temp
# 0          90.0          87.8          83.2
# 1          91.2          91.4          84.6
# ...

# %% [markdown]
# ## loading CSV file USDA Rice yield

# %%
Cali_weatherDAM.to_csv("output_data/California_weather.csv", index = False)

# %%
cali_path = "output_data/California_rice_yield.csv"
California_rice_yield = pd.read_csv(cali_path)
California_rice_yield.head()
# Out:
#    Year  Rice_year_yield
# 0  1980         7.956813
# 1  1981         8.525157
# 2  1982         8.278051
# 3  1983         8.698131
# 4  1984         8.796974

# %% [markdown]
# ## merging with weather dataframe

# %%
cali_weather_yield = pd.merge(Cali_weatherDAM, California_rice_yield, on="Year")
cali_weather_yield.head()
# Out:
#    Year  Seasonal_Drought  Seasonal_Temp  Seasonal_Max  Jul Drought  \
# 0  1980         -0.473333      72.333333     87.000000         2.38
# 1  1981          0.920000      73.900000     89.066667        -2.49
# 2  1982          3.073333      71.366667     85.000000         3.09
# 3  1983          3.503333      72.200000     85.800000         5.82
# 4  1984          3.543333      74.700000     88.900000         0.16
#
#    Aug Drought  Sep Drought  Jul_ave_temp  Aug_ave_temp  Sep_ave_temp  \
# 0        -0.16        -0.16          75.4          73.0          68.6
# 1        -2.64        -2.64          75.5          75.8          70.4
# 2         3.07         3.07          73.1          73.9          67.1
# 3         6.45         6.45          71.9          73.7          71.0
# 4         0.50         0.50          77.0          74.9          72.2
#
#    Jul_Max_Temp  Aug_Max_Temp  Sep_Max_temp  Rice_year_yield
# 0          90.0          87.8          83.2         7.956813
# ...

# %% [markdown]
# ## creating graphs rice yield compared to california weather

# %%
x_axis = cali_weather_yield['Year']
y_axis=  cali_weather_yield['Rice_year_yield']
y2_axis= cali_weather_yield['Seasonal_Drought']


fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")

ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Season Yield (tons/hectares)",fontsize=14)
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))

ax2=ax.twinx()
#ax2=corn_y.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Drought Severity")
ax2.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
#severity.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()
plt.title("Season Rice Yield vs Drought Severity", fontsize=14)

plt.legend(loc="upper left")
plt.savefig("output_data/Rice-Sea-Drought.png")
plt.show()

# %%
x_axis = cali_weather_yield['Year']
y_axis=  cali_weather_yield['Rice_year_yield']
y2_axis= cali_weather_yield['Seasonal_Temp']


fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")

ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Season Yield (tons/hectares)",fontsize=14)
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))

ax2=ax.twinx()
#ax2=corn_y.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Season temp")
ax2.set_ylabel("Season Average Temp (F)",fontsize=14)
#severity.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()
plt.title("Season Rice Yield vs Season Average Temperature", fontsize=14)

plt.legend(loc="upper left")
plt.savefig("output_data/Rice-Sea-aveT.png")
plt.show()

# %%
x_axis = cali_weather_yield['Year']
y_axis=  cali_weather_yield['Rice_year_yield']
y2_axis= cali_weather_yield['Seasonal_Max']


fig,ax=plt.subplots(figsize=(10,5))
ax.plot(x_axis, y_axis, color="forestgreen", marker="o", label="Yield")

ax.set_xlabel("Year",fontsize=14)
ax.set_ylabel("Season Yield (tons/hectares)",fontsize=14)
plt.legend(loc="center left", bbox_to_anchor=(0,0.6,0.5,0.5))

ax2=ax.twinx()
#ax2=corn_y.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x_axis, y2_axis,color="orange",marker="o", label="Season temp")
ax2.set_ylabel("Season Max Temp (F)",fontsize=14)
#severity.set_ylabel("Aug Palmer Drought Severity Index (PDSI)",fontsize=14)
plt.tight_layout()
plt.title("Season Rice Yield vs Season Max Temperature", fontsize=14)

plt.legend(loc="upper left")
plt.savefig("output_data/Rice-Sea-MaxT.png")
plt.show()

# %% [markdown]
# ## loading CSV weather yearly change and corn yield change per year in Iowa

# %%
change_path = "output_data/corn_change_yied.csv"
corn_change = pd.read_csv(change_path)
corn_change.head()
# Out:
#    year  yield change  average temp change  Max temp change  drought change
# 0  1980           -17             3.200000         3.233333       -3.113333
# 1  1981            15            -2.066667        -3.166667        1.393333
# 2  1982            -5            -1.366667        -1.500000        2.153333
# 3  1983           -33             3.766667         6.366667        0.430000
# 4  1984            25            -3.033333        -2.833333        0.040000

# %% [markdown]
# ## creating graphs

# %%
x_axis = corn_change['year']
y_axis=  corn_change['yield change']
plt.figure(figsize=(12,5))
Corn_change = plt.plot(x_axis,y_axis, color="red", marker="o")

plt.title("Corn Yield Change", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.ylabel("Yield Change", fontsize=14)
plt.tight_layout()
plt.savefig("output_data/Corn_yield_change.png")
plt.show()

# %%
x_axis = corn_change['year']
y_axis=  corn_change['drought change']
plt.figure(figsize=(12,5))
Corn_change = plt.plot(x_axis,y_axis, color="blue", marker="o")

plt.title("Change in Palmer Drought Severity Index", fontsize=14)
plt.xlabel("Years", fontsize=14)
plt.ylabel("Palmer Drought Severity Index (change)", fontsize=14)
plt.tight_layout()
plt.savefig("output_data/Drought_yield_change.png")
plt.show()

# %% [markdown]
# ## loading CSV of normalized yield (normal hearthy corn yield and weather affected corn yield)

# %%
Normal_path= "output_data/Normal_affected_corn.csv"
nor_aff = pd.read_csv(Normal_path)
nor_aff.head()
# Out:
#      Normal  Affected
# 0  0.978862  0.887805
# 1  1.024390  0.762602
# 2  0.944715  0.819512
# 3  1.035772  0.648780
# 4  0.944715  0.808130

# %%
Normal_mean = nor_aff["Normal"].mean()
Affected_mean = nor_aff["Affected"].mean() 

Normal_std = nor_aff["Normal"].std()
Affected_std = nor_aff["Affected"].std()


stats = pd.DataFrame({"tield":["stats"], "N_mean": Normal_mean, "A_mean": Affected_mean})

stats
# Out:
#    tield  N_mean    A_mean
# 0  stats     1.0  0.743747

# %% [markdown]
# ## creating bar plot

# %%
stats = [1.0, 0.744]
x_axis = np.arange(len(stats))
x_axis

plt.figure(figsize=(10,5))
plt.bar(x=x_axis,height=stats, color='orange', alpha=0.5, align="center")
plt.xticks(x_axis, ["Normal", "Affected"], fontsize=14)
plt.ylim(0, max(stats)*1.35)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.title("Normal Yield vs Weather Affected Yield", Fontsize=14)
plt.ylabel("Normalized Yield", fontsize=14)
plt.tight_layout()
plt.savefig("output_data/Normalize_data.png")
# Out:
# C:\Users\zorta\anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## doing anova to determine if there differences between yields

# %%
st.f_oneway(nor_aff['Normal'], nor_aff['Affected'])
# Out:
# F_onewayResult(statistic=105.342625536768, pvalue=5.965494854271489e-12)

# %% [markdown]
# ## Shapiro-Wilk test to determine normality, The test reject the hypothesis of normality when p-values is less or equal to 0.05

# %%
pvalue = st.shapiro(nor_aff['Normal'])
print(pvalue)

pvalue2 = st.shapiro(nor_aff['Affected'])
print(pvalue2)
# Out:
# (0.9547209739685059, 0.5037661194801331)
# (0.9285202622413635, 0.1828833818435669)
