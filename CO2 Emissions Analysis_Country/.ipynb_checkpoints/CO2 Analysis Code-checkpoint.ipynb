# %% [markdown]
# #### Import Dependencies

# %%
# define keys and dependencies: 
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# #### Set the path to the data file

# %%
# Obtaining the data from Co2_data Csv:
f_path=os.path.join("CO2_data.csv")
Co2_Emissions=pd.read_csv(f_path)
Co2_Emissions.head(100)
# Out:
#         country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0   Afghanistan  1949  0.015              NaN             NaN
# 1   Afghanistan  1950  0.084          475.000           0.070
# 2   Afghanistan  1951  0.092            8.696           0.007
# 3   Afghanistan  1952  0.092            0.000           0.000
# 4   Afghanistan  1953  0.106           16.000           0.015
# ..          ...   ...    ...              ...             ...
# 95       Africa  1776  0.000              NaN           0.000
# 96       Africa  1777  0.000              NaN           0.000
# 97       Africa  1778  0.000              NaN           0.000
# 98       Africa  1779  0.000              NaN           0.000
# 99       Africa  1780  0.000              NaN           0.000
#
#     consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 0               NaN        NaN              NaN             0.0
# 1               NaN        NaN              NaN             0.0
# 2               NaN        NaN              NaN             0.0
# 3               NaN        NaN              NaN             0.0
# 4               NaN        NaN              NaN             0.0
# ..              ...        ...              ...             ...
# 95              NaN        NaN              NaN             NaN
# 96              NaN        NaN              NaN             NaN
# 97              NaN        NaN              NaN             NaN
# 98              NaN        NaN              NaN             NaN
# 99              NaN        NaN              NaN             NaN
#
#     consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 0                          NaN  ...             NaN      NaN
# 1                          NaN  ...             NaN      NaN
# 2                          NaN  ...             NaN      NaN
# 3                          NaN  ...             NaN      NaN
# 4                          NaN  ...             NaN      NaN
# ..                         ...  ...             ...      ...
# 95                         NaN  ...             NaN      NaN
# 96                         NaN  ...             NaN      NaN
# 97                         NaN  ...             NaN      NaN
# 98                         NaN  ...             NaN      NaN
# 99                         NaN  ...             NaN      NaN
#
#     methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                  NaN            NaN                       NaN
# 1                  NaN            NaN                       NaN
# 2                  NaN            NaN                       NaN
# 3                  NaN            NaN                       NaN
# 4                  NaN            NaN                       NaN
# ..                 ...            ...                       ...
# 95                 NaN            NaN                       NaN
# 96                 NaN            NaN                       NaN
# 97                 NaN            NaN                       NaN
# 98                 NaN            NaN                       NaN
# 99                 NaN            NaN                       NaN
#
#     primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                          NaN                NaN             NaN   7663783.0
# 1                          NaN                NaN             NaN   7752000.0
# 2                          NaN                NaN             NaN   7840000.0
# 3                          NaN                NaN             NaN   7936000.0
# 4                          NaN                NaN             NaN   8040000.0
# ..                         ...                ...             ...         ...
# 95                         NaN                NaN             NaN         NaN
# 96                         NaN                NaN             NaN         NaN
# 97                         NaN                NaN             NaN         NaN
# 98                         NaN                NaN             NaN         NaN
# 99                         NaN                NaN             NaN  84262792.0
#
#              gdp
# 0            NaN
# 1   1.949480e+10
# 2   2.006385e+10
# 3   2.074235e+10
# 4   2.201546e+10
# ..           ...
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
#
# [100 rows x 37 columns]

# %% [markdown]
# #### List all the columns in the table

# %%
# Defining you columns to narrow your area of analysis:
Co2_Emissions.columns
# Out:
# Index(['country', 'year', 'co2', 'co2_growth_prct', 'co2_growth_abs',
#        'consumption_co2', 'trade_co2', 'trade_co2_share', 'co2_per_capita',
#        'consumption_co2_per_capita', 'share_global_co2', 'cumulative_co2',
#        'share_global_cumulative_co2', 'co2_per_gdp', 'consumption_co2_per_gdp',
#        'co2_per_unit_energy', 'cement_co2', 'coal_co2', 'flaring_co2',
#        'gas_co2', 'oil_co2', 'cement_co2_per_capita', 'coal_co2_per_capita',
#        'flaring_co2_per_capita', 'gas_co2_per_capita', 'oil_co2_per_capita',
#        'total_ghg', 'ghg_per_capita', 'methane', 'methane_per_capita',
#        'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'primary_energy_consumption', 'energy_per_capita', 'energy_per_gdp',
#        'population', 'gdp'],
#       dtype='object')

# %% [markdown]
# #### New table that contains the columns within the area of interest analysis

# %%
# Check for Null Values and create a new data frame: 
Co2_Emissions.isnull().any()
Co2_Emissions.count()
Co2_Emissions_df=Co2_Emissions[["country","year","co2","co2_growth_prct","consumption_co2","cumulative_co2","total_ghg",'ghg_per_capita', 'methane', 'methane_per_capita',
       'nitrous_oxide', 'nitrous_oxide_per_capita','primary_energy_consumption',"co2_growth_abs", 'energy_per_capita',"co2_per_capita",'population']]
Co2_Emissions_df=Co2_Emissions_df.loc[Co2_Emissions_df["year"] >=1980]
Co2_Emissions_df=Co2_Emissions_df.reset_index()
del Co2_Emissions_df["index"]

# %%
Co2_Emissions_df.groupby("country").count()
Co2_Emissions_df
# Out:
#           country  year     co2  co2_growth_prct  consumption_co2  \
# 0     Afghanistan  1980   1.757          -21.383              NaN
# 1     Afghanistan  1981   1.979           12.655              NaN
# 2     Afghanistan  1982   2.096            5.869              NaN
# 3     Afghanistan  1983   2.520           20.260              NaN
# 4     Afghanistan  1984   2.822           11.996              NaN
# ...           ...   ...     ...              ...              ...
# 9438     Zimbabwe  2014  11.962            2.838           12.760
# 9439     Zimbabwe  2015  12.163            1.685           13.010
# 9440     Zimbabwe  2016  10.807          -11.146           11.809
# 9441     Zimbabwe  2017  12.026           11.274           12.531
# 9442     Zimbabwe  2018  12.263            1.969              NaN
#
#       cumulative_co2  total_ghg  ghg_per_capita  methane  methane_per_capita  \
# 0             31.814        NaN             NaN      NaN                 NaN
# 1             33.793        NaN             NaN      NaN                 NaN
# 2             35.888        NaN             NaN      NaN                 NaN
# 3             38.409        NaN             NaN      NaN                 NaN
# 4             41.231        NaN             NaN      NaN                 NaN
# ...              ...        ...             ...      ...                 ...
# 9438         671.105      66.10           4.865    11.24               0.827
# 9439         683.268      67.49           4.885    11.87               0.859
# 9440         694.076      65.98           4.703    11.92               0.850
# 9441         706.102        NaN             NaN      NaN                 NaN
# 9442         718.364        NaN             NaN      NaN                 NaN
#
#       nitrous_oxide  nitrous_oxide_per_capita  primary_energy_consumption  \
# 0               NaN                       NaN                         NaN
# 1               NaN                       NaN                         NaN
# 2               NaN                       NaN                         NaN
# 3               NaN                       NaN                         NaN
# 4               NaN                       NaN                         NaN
# ...             ...                       ...                         ...
# 9438           6.27                     0.461                         NaN
# 9439           6.68                     0.484                         NaN
# 9440           6.55                     0.467                         NaN
# 9441            NaN                       NaN                         NaN
# 9442            NaN                       NaN                         NaN
#
#       co2_growth_abs  energy_per_capita  co2_per_capita  population
# 0             -0.478                NaN             0.0  13357000.0
# 1              0.222                NaN             0.0  13172000.0
# 2              0.116                NaN             0.0  12883000.0
# 3              0.425                NaN             0.0  12538000.0
# 4              0.302                NaN             0.0  12204000.0
# ...              ...                ...             ...         ...
# 9438           0.330                NaN             0.0  13587000.0
# 9439           0.202                NaN             0.0  13815000.0
# 9440          -1.356                NaN             0.0  14030000.0
# 9441           1.218                NaN             0.0  14237000.0
# 9442           0.237                NaN             0.0  14439000.0
#
# [9443 rows x 17 columns]

# %%
# Analyzing Co2 and GHG by country
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="World"]
Co2_Emissions_USA=Co2_Emissions_USA.reset_index(drop=True)
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.methane,color="green",label="CH4")
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.nitrous_oxide,color="blue",label="N2O")
plt.ylabel("CH4/N2O (Millions Per Tonnes)")
ax2=ax.twinx()
ax2.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.co2,color="red",label="CO2")
plt.ylabel("CO2(Millions Per Tonnes)")
plt.xlim(1990,2018)
plt.grid()
fig.legend(loc="best")
# Out:
# C:\Users\osama\anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   del sys.path[0]

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_USA=Co2_Emissions_USA.reset_index(drop=True)
Co2_Emissions_USA_chart=Co2_Emissions_USA.plot.line(x='year', y='co2_growth_abs',color="blue",alpha=0.5,figsize=(12,5))
plt.xlabel("Year")
plt.xlim(1990,2018)
plt.ylabel("Cumulative CO2 (Million Tonnes)")

plt.xticks(rotation=90)
plt.grid()
fig.legend(loc="best")
# Out:
# C:\Users\osama\anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   # Remove the CWD from sys.path while we load stuff.

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Russia=Co2_Emissions_df[Co2_Emissions_df.country=="Russia"]
Co2_Emissions_Europe=Co2_Emissions_df[Co2_Emissions_df.country=="Europe"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.co2,color="green",label="United States")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.co2,color="red",label="China")
ax.plot(Co2_Emissions_Russia.year,Co2_Emissions_Russia.co2,color="blue",label="Russia")
ax.plot(Co2_Emissions_Europe.year,Co2_Emissions_Europe.co2,color="black",label="Europe")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.co2,color="Orange",label="India")
plt.grid()
fig.legend(loc="best")
# Out:
# C:\Users\osama\anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   del sys.path[0]

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Russia=Co2_Emissions_df[Co2_Emissions_df.country=="Russia"]
Co2_Emissions_Germany=Co2_Emissions_df[Co2_Emissions_df.country=="Germany"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.methane,color="green",label="United States")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.methane,color="red",label="China")
ax.plot(Co2_Emissions_Russia.year,Co2_Emissions_Russia.methane,color="blue",label="Russia")
ax.plot(Co2_Emissions_Germany.year,Co2_Emissions_Germany.methane,color="black",label="Germany")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.methane,color="Orange",label="India")
plt.grid()
fig.legend(loc="best")
# Out:
# C:\Users\osama\anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   del sys.path[0]

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Russia=Co2_Emissions_df[Co2_Emissions_df.country=="Russia"]
Co2_Emissions_Europe=Co2_Emissions_df[Co2_Emissions_df.country=="Europe"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.nitrous_oxide,color="green",label="United States")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.nitrous_oxide,color="red",label="China")
ax.plot(Co2_Emissions_Russia.year,Co2_Emissions_Russia.nitrous_oxide,color="blue",label="Russia")
ax.plot(Co2_Emissions_Germany.year,Co2_Emissions_Germany.nitrous_oxide,color="black",label="Europe")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.nitrous_oxide,color="Orange",label="India")
plt.grid()
fig.legend(loc="best")
# Out:
# C:\Users\osama\anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   del sys.path[0]

# %%
# Examining Top Co2 Emmissions Country through sorting Values:
Co2_Emissions_Sorted=Co2_Emissions.groupby("country").mean()
Co2_Emissions_Sorted=Co2_Emissions.sort_values(by=['co2'],ascending=False)
Co2_Emissions_Sorted.head(50)
# Out:
#               country  year        co2  co2_growth_prct  co2_growth_abs  \
# 23662           World  2018  36572.754            1.160         419.493
# 23661           World  2017  36153.262            1.340         478.162
# 23660           World  2016  35675.099            0.599         212.353
# 23658           World  2014  35505.827            0.846         297.941
# 23659           World  2015  35462.747           -0.121         -43.080
# 23657           World  2013  35207.886            0.826         288.597
# 23656           World  2012  34919.289            1.636         561.923
# 23655           World  2011  34357.366            3.903        1290.715
# 23654           World  2010  33066.651            4.896        1543.508
# 23652           World  2008  31875.756            3.224         995.610
# 23653           World  2009  31523.143           -1.106        -352.613
# 23651           World  2007  30880.145            1.959         593.309
# 23650           World  2006  30286.836            3.527        1031.930
# 23649           World  2005  29254.906            3.786        1067.307
# 23648           World  2004  28187.599            4.916        1320.861
# 23647           World  2003  26866.738            5.384        1372.548
# 23646           World  2002  25494.191            1.417         356.191
# 23645           World  2001  25138.000            2.359         579.309
# 23644           World  2000  24558.691            2.625         628.130
# 23642           World  1998  23984.984            0.291          69.655
# 23643           World  1999  23930.561           -0.227         -54.422
# 23641           World  1997  23915.329            1.668         392.350
# 23640           World  1996  23522.979            2.241         515.554
# 23639           World  1995  23007.425            2.102         473.592
# 15452        Non-OECD  2018  22654.218            3.150         691.749
# 23638           World  1994  22533.833            1.718         380.690
# 23635           World  1991  22429.377            1.116         247.570
# 15392  Non KP Annex B  2018  22274.871            2.948         637.763
# 23636           World  1992  22195.105           -1.044        -234.272
# 23634           World  1990  22181.807            0.124          27.472
# 23633           World  1989  22154.336            2.183         473.226
# 23637           World  1993  22153.143           -0.189         -41.962
# 15451        Non-OECD  2017  21962.468            1.778         383.704
# 23632           World  1988  21681.109            3.676         768.696
# 15391  Non KP Annex B  2017  21637.108            1.966         417.186
# 15450        Non-OECD  2016  21578.764            0.934         199.577
# 15449        Non-OECD  2015  21379.187            0.415          88.379
# 15448        Non-OECD  2014  21290.808            2.123         442.601
# 15390  Non KP Annex B  2016  21219.922            1.174         246.147
# 15389  Non KP Annex B  2015  20973.776            0.721         150.202
# 23631           World  1987  20912.413            2.532         516.464
# 15447        Non-OECD  2013  20848.207            0.358          74.474
# 15388  Non KP Annex B  2014  20823.573            2.342         476.431
# 15446        Non-OECD  2012  20773.733            3.489         700.276
# 23630           World  1986  20395.950            3.048         603.328
# 15387  Non KP Annex B  2013  20347.143            0.715         144.433
# 15386  Non KP Annex B  2012  20202.710            3.755         731.119
# 1324             Asia  2018  20074.101            3.088         601.250
# 15445        Non-OECD  2011  20073.457            6.619        1246.171
# 23629           World  1985  19792.622            2.996         575.756
#
#        consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 23662              NaN        NaN              NaN             0.0
# 23661              NaN        NaN              NaN             0.0
# 23660              NaN        NaN              NaN             0.0
# 23658              NaN        NaN              NaN             0.0
# 23659              NaN        NaN              NaN             0.0
# 23657              NaN        NaN              NaN             0.0
# 23656              NaN        NaN              NaN             0.0
# 23655              NaN        NaN              NaN             0.0
# 23654              NaN        NaN              NaN             0.0
# 23652              NaN        NaN              NaN             0.0
# 23653              NaN        NaN              NaN             0.0
# 23651              NaN        NaN              NaN             0.0
# 23650              NaN        NaN              NaN             0.0
# 23649              NaN        NaN              NaN             0.0
# 23648              NaN        NaN              NaN             0.0
# 23647              NaN        NaN              NaN             0.0
# 23646              NaN        NaN              NaN             0.0
# 23645              NaN        NaN              NaN             0.0
# 23644              NaN        NaN              NaN             0.0
# 23642              NaN        NaN              NaN             0.0
# 23643              NaN        NaN              NaN             0.0
# 23641              NaN        NaN              NaN             0.0
# 23640              NaN        NaN              NaN             0.0
# 23639              NaN        NaN              NaN             0.0
# 15452              NaN        NaN              NaN             NaN
# 23638              NaN        NaN              NaN             0.0
# 23635              NaN        NaN              NaN             0.0
# 15392              NaN        NaN              NaN             NaN
# 23636              NaN        NaN              NaN             0.0
# 23634              NaN        NaN              NaN             0.0
# 23633              NaN        NaN              NaN             0.0
# 23637              NaN        NaN              NaN             0.0
# 15451        20425.112  -1537.356           -0.001             NaN
# 23632              NaN        NaN              NaN             0.0
# 15391        20474.273  -1162.835           -0.001             NaN
# 15450        20114.465  -1464.299           -0.001             NaN
# 15449        19879.277  -1499.910           -0.001             NaN
# 15448        19710.147  -1580.660           -0.001             NaN
# 15390        20125.551  -1094.372           -0.001             NaN
# 15389        19850.091  -1123.685           -0.001             NaN
# 23631              NaN        NaN              NaN             0.0
# 15447        19306.299  -1541.909           -0.001             NaN
# 15388        19617.133  -1206.440           -0.001             NaN
# 15446        19131.899  -1641.834           -0.001             NaN
# 23630              NaN        NaN              NaN             0.0
# 15387        19180.247  -1166.895           -0.001             NaN
# 15386        18933.079  -1269.631           -0.001             NaN
# 1324               NaN        NaN              NaN             0.0
# 15445        18282.689  -1790.768           -0.001             NaN
# 23629              NaN        NaN              NaN             0.0
#
#        consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 23662                         NaN  ...             NaN      NaN
# 23661                         NaN  ...             NaN      NaN
# 23660                         NaN  ...           6.613  8550.06
# 23658                         NaN  ...           6.777  8477.25
# 23659                         NaN  ...           6.756  8660.01
# 23657                         NaN  ...           6.790  8339.46
# 23656                         NaN  ...           6.785  8374.14
# 23655                         NaN  ...           6.789  8280.11
# 23654                         NaN  ...           6.692  8170.01
# 23652                         NaN  ...           6.621  8017.25
# 23653                         NaN  ...           6.538  8100.53
# 23651                         NaN  ...           6.648  7945.85
# 23650                         NaN  ...           6.601  7927.19
# 23649                         NaN  ...           6.627  7749.03
# 23648                         NaN  ...           6.570  7770.13
# 23647                         NaN  ...           6.375  7586.58
# 23646                         NaN  ...           6.320  7561.80
# 23645                         NaN  ...           6.168  7262.65
# 23644                         NaN  ...           6.091  7173.99
# 23642                         NaN  ...           6.178  7274.29
# 23643                         NaN  ...           6.070  7207.23
# 23641                         NaN  ...           6.324  7369.05
# 23640                         NaN  ...           6.185  7152.83
# 23639                         NaN  ...           6.269  7283.49
# 15452                         NaN  ...             NaN      NaN
# 23638                         NaN  ...           6.231  7274.33
# 23635                         NaN  ...           6.488  7387.74
# 15392                         NaN  ...             NaN      NaN
# 23636                         NaN  ...           6.362  7322.48
# 23634                         NaN  ...           6.564  7415.58
# 23633                         NaN  ...             NaN      NaN
# 23637                         NaN  ...           6.285  7300.62
# 15451                         NaN  ...             NaN      NaN
# 23632                         NaN  ...             NaN      NaN
# 15391                         NaN  ...             NaN      NaN
# 15450                         NaN  ...             NaN      NaN
# 15449                         NaN  ...             NaN      NaN
# 15448                         NaN  ...             NaN      NaN
# 15390                         NaN  ...             NaN      NaN
# 15389                         NaN  ...             NaN      NaN
# 23631                         NaN  ...             NaN      NaN
# 15447                         NaN  ...             NaN      NaN
# 15388                         NaN  ...             NaN      NaN
# 15446                         NaN  ...             NaN      NaN
# 23630                         NaN  ...             NaN      NaN
# 15387                         NaN  ...             NaN      NaN
# 15386                         NaN  ...             NaN      NaN
# 1324                          NaN  ...             NaN      NaN
# 15445                         NaN  ...             NaN      NaN
# 23629                         NaN  ...             NaN      NaN
#
#        methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 23662                 NaN            NaN                       NaN
# 23661                 NaN            NaN                       NaN
# 23660               1.146        3054.00                     0.409
# 23658               1.162        2999.32                     0.411
# 23659               1.173        3052.82                     0.414
# 23657               1.157        2941.00                     0.408
# 23656               1.175        2970.41                     0.417
# 23655               1.176        2943.30                     0.418
# 23654               1.174        2860.55                     0.411
# 23652               1.181        2802.99                     0.413
# 23653               1.179        2803.03                     0.408
# 23651               1.185        2822.20                     0.421
# 23650               1.197        2774.44                     0.419
# 23649               1.185        2740.70                     0.419
# 23648               1.203        2742.89                     0.425
# 23647               1.189        2676.14                     0.419
# 23646               1.200        2662.79                     0.423
# 23645               1.167        2592.42                     0.417
# 23644               1.168        2554.89                     0.416
# 23642               1.215        2599.16                     0.434
# 23643               1.188        2572.36                     0.424
# 23641               1.248        2587.71                     0.438
# 23640               1.228        2577.46                     0.442
# 23639               1.268        2570.66                     0.448
# 15452                 NaN            NaN                       NaN
# 23638               1.285        2514.99                     0.444
# 23635               1.364        2447.93                     0.452
# 15392                 NaN            NaN                       NaN
# 23636               1.332        2440.49                     0.444
# 23634               1.392        2460.54                     0.462
# 23633                 NaN            NaN                       NaN
# 23637               1.308        2428.77                     0.435
# 15451                 NaN            NaN                       NaN
# 23632                 NaN            NaN                       NaN
# 15391                 NaN            NaN                       NaN
# 15450                 NaN            NaN                       NaN
# 15449                 NaN            NaN                       NaN
# 15448                 NaN            NaN                       NaN
# 15390                 NaN            NaN                       NaN
# 15389                 NaN            NaN                       NaN
# 23631                 NaN            NaN                       NaN
# 15447                 NaN            NaN                       NaN
# 15388                 NaN            NaN                       NaN
# 15446                 NaN            NaN                       NaN
# 23630                 NaN            NaN                       NaN
# 15387                 NaN            NaN                       NaN
# 15386                 NaN            NaN                       NaN
# 1324                  NaN            NaN                       NaN
# 15445                 NaN            NaN                       NaN
# 23629                 NaN            NaN                       NaN
#
#        primary_energy_consumption  energy_per_capita  energy_per_gdp  \
# 23662                         NaN                NaN             NaN
# 23661                         NaN                NaN             NaN
# 23660                  153848.433          20612.002           1.444
# 23658                  150489.502          20628.307           1.475
# 23659                  151720.063          20558.840           1.447
# 23657                  149089.930          20676.546           1.502
# 23656                  146252.983          20524.349           1.513
# 23655                  144255.091          20487.305           1.535
# 23654                  140722.294          20227.951           1.591
# 23652                  136130.341          20051.342           1.641
# 23653                  134213.756          19528.344           1.629
# 23651                  134465.270          20051.645           1.684
# 23650                  130323.332          19675.847           1.736
# 23649                  126626.721          19356.240           1.790
# 23648                  122395.789          18943.318           1.855
# 23647                  116667.070          18282.979           1.869
# 23646                  112538.209          17858.182           1.860
# 23645                  110048.804          17685.265           1.877
# 23644                  108822.059          17713.382           1.899
# 23642                  104270.798          17422.621           2.000
# 23643                  106165.384          17506.794           1.966
# 23641                  103650.060          17552.795           2.018
# 23640                  102592.218          17612.725           2.061
# 23639                   99620.580          17342.773           2.062
# 15452                         NaN                NaN             NaN
# 23638                   97641.655          17241.580           2.100
# 23635                   94998.441          17545.876           2.176
# 15392                         NaN                NaN             NaN
# 23636                   95643.593          17393.160           2.136
# 23634                   94383.408          17717.161           2.183
# 23633                   93310.190          17815.989           2.205
# 23637                   96369.906          17265.647           2.121
# 15451                         NaN                NaN             NaN
# 23632                   91500.967          17782.972           2.234
# 15391                         NaN                NaN             NaN
# 15450                         NaN                NaN             NaN
# 15449                         NaN                NaN             NaN
# 15448                         NaN                NaN             NaN
# 15390                         NaN                NaN             NaN
# 15389                         NaN                NaN             NaN
# 23631                   88171.095          17450.908           2.243
# 15447                         NaN                NaN             NaN
# 15388                         NaN                NaN             NaN
# 15446                         NaN                NaN             NaN
# 23630                   85194.750          17174.395           2.252
# 15387                         NaN                NaN             NaN
# 15386                         NaN                NaN             NaN
# 1324                          NaN                NaN             NaN
# 15445                         NaN                NaN             NaN
# 23629                   83360.788          17113.964           2.287
#
#          population           gdp
# 23662  7.631091e+09           NaN
# 23661  7.547859e+09           NaN
# 23660  7.464022e+09  1.065610e+14
# 23658  7.295291e+09  1.019990e+14
# 23659  7.379797e+09  1.048550e+14
# 23657  7.210582e+09  9.927970e+13
# 23656  7.125828e+09  9.664920e+13
# 23655  7.041194e+09  9.395210e+13
# 23654  6.956824e+09  8.845410e+13
# 23652  6.789089e+09  8.296380e+13
# 23653  6.872767e+09  8.239050e+13
# 23651  6.705947e+09  7.986160e+13
# 23650  6.623518e+09  7.507390e+13
# 23649  6.541907e+09  7.072990e+13
# 23648  6.461159e+09  6.599580e+13
# 23647  6.381185e+09  6.242520e+13
# 23646  6.301773e+09  6.050640e+13
# 23645  6.222627e+09  5.863180e+13
# 23644  6.143494e+09  5.730170e+13
# 23642  5.984794e+09  5.213050e+13
# 23643  6.064239e+09  5.401150e+13
# 23641  5.905046e+09  5.135240e+13
# 23640  5.824892e+09  4.976750e+13
# 23639  5.744213e+09  4.832220e+13
# 15452           NaN           NaN
# 23638  5.663150e+09  4.650490e+13
# 23635  5.414289e+09  4.366400e+13
# 15392           NaN           NaN
# 23636  5.498920e+09  4.477600e+13
# 23634  5.327231e+09  4.324000e+13
# 23633  5.237441e+09  4.232670e+13
# 23637  5.581598e+09  4.544660e+13
# 15451           NaN           NaN
# 23632  5.145426e+09  4.095260e+13
# 15391           NaN           NaN
# 15450           NaN           NaN
# 15449           NaN           NaN
# 15448           NaN           NaN
# 15390           NaN           NaN
# 15389           NaN           NaN
# 23631  5.052522e+09  3.931240e+13
# 15447           NaN           NaN
# 15388           NaN           NaN
# 15446           NaN           NaN
# 23630  4.960568e+09  3.783130e+13
# 15387           NaN           NaN
# 15386           NaN           NaN
# 1324   4.560667e+09           NaN
# 15445           NaN           NaN
# 23629  4.870922e+09  3.645000e+13
#
# [50 rows x 37 columns]

# %%
Co2_Emissions_country=Co2_Emissions.set_index("country")
Co2_Emissions_country=Co2_Emissions_country.loc[Co2_Emissions_country["year"] >=1990]
Co2_Emissions_country=Co2_Emissions_country.loc["World"]
Co2_Emissions_country.to_csv("CO2 Emissions_world.csv",index=False)
