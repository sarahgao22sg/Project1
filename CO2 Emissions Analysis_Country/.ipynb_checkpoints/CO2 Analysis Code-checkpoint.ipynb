# %% [markdown]
# #### Import Dependencies

# %%
# define keys and dependencies: 
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# #### Set the path to the data file

# %%
# Obtaining the data from Co2_data Csv:
f_path=os.path.join("CO2_data.csv")
Co2_Emissions=pd.read_csv(f_path)
Co2_Emissions.head(100)
# Out:
#         country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0   Afghanistan  1949  0.015              NaN             NaN
# 1   Afghanistan  1950  0.084          475.000           0.070
# 2   Afghanistan  1951  0.092            8.696           0.007
# 3   Afghanistan  1952  0.092            0.000           0.000
# 4   Afghanistan  1953  0.106           16.000           0.015
# ..          ...   ...    ...              ...             ...
# 95       Africa  1776  0.000              NaN           0.000
# 96       Africa  1777  0.000              NaN           0.000
# 97       Africa  1778  0.000              NaN           0.000
# 98       Africa  1779  0.000              NaN           0.000
# 99       Africa  1780  0.000              NaN           0.000
#
#     consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 0               NaN        NaN              NaN             0.0
# 1               NaN        NaN              NaN             0.0
# 2               NaN        NaN              NaN             0.0
# 3               NaN        NaN              NaN             0.0
# 4               NaN        NaN              NaN             0.0
# ..              ...        ...              ...             ...
# 95              NaN        NaN              NaN             NaN
# 96              NaN        NaN              NaN             NaN
# 97              NaN        NaN              NaN             NaN
# 98              NaN        NaN              NaN             NaN
# 99              NaN        NaN              NaN             NaN
#
#     consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 0                          NaN  ...             NaN      NaN
# 1                          NaN  ...             NaN      NaN
# 2                          NaN  ...             NaN      NaN
# 3                          NaN  ...             NaN      NaN
# 4                          NaN  ...             NaN      NaN
# ..                         ...  ...             ...      ...
# 95                         NaN  ...             NaN      NaN
# 96                         NaN  ...             NaN      NaN
# 97                         NaN  ...             NaN      NaN
# 98                         NaN  ...             NaN      NaN
# 99                         NaN  ...             NaN      NaN
#
#     methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                  NaN            NaN                       NaN
# 1                  NaN            NaN                       NaN
# 2                  NaN            NaN                       NaN
# 3                  NaN            NaN                       NaN
# 4                  NaN            NaN                       NaN
# ..                 ...            ...                       ...
# 95                 NaN            NaN                       NaN
# 96                 NaN            NaN                       NaN
# 97                 NaN            NaN                       NaN
# 98                 NaN            NaN                       NaN
# 99                 NaN            NaN                       NaN
#
#     primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                          NaN                NaN             NaN   7663783.0
# 1                          NaN                NaN             NaN   7752000.0
# 2                          NaN                NaN             NaN   7840000.0
# 3                          NaN                NaN             NaN   7936000.0
# 4                          NaN                NaN             NaN   8040000.0
# ..                         ...                ...             ...         ...
# 95                         NaN                NaN             NaN         NaN
# 96                         NaN                NaN             NaN         NaN
# 97                         NaN                NaN             NaN         NaN
# 98                         NaN                NaN             NaN         NaN
# 99                         NaN                NaN             NaN  84262792.0
#
#              gdp
# 0            NaN
# 1   1.949480e+10
# 2   2.006385e+10
# 3   2.074235e+10
# 4   2.201546e+10
# ..           ...
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
#
# [100 rows x 37 columns]

# %% [markdown]
# #### List all the columns in the table

# %%
# Defining you columns to narrow your area of analysis:
Co2_Emissions.columns
# Out:
# Index(['country', 'year', 'co2', 'co2_growth_prct', 'co2_growth_abs',
#        'consumption_co2', 'trade_co2', 'trade_co2_share', 'co2_per_capita',
#        'consumption_co2_per_capita', 'share_global_co2', 'cumulative_co2',
#        'share_global_cumulative_co2', 'co2_per_gdp', 'consumption_co2_per_gdp',
#        'co2_per_unit_energy', 'cement_co2', 'coal_co2', 'flaring_co2',
#        'gas_co2', 'oil_co2', 'cement_co2_per_capita', 'coal_co2_per_capita',
#        'flaring_co2_per_capita', 'gas_co2_per_capita', 'oil_co2_per_capita',
#        'total_ghg', 'ghg_per_capita', 'methane', 'methane_per_capita',
#        'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'primary_energy_consumption', 'energy_per_capita', 'energy_per_gdp',
#        'population', 'gdp'],
#       dtype='object')

# %% [markdown]
# #### New table that contains the columns within the area of interest analysis

# %%
# Check for Null Values and create a new data frame: 
Co2_Emissions.isnull().any()
Co2_Emissions.count()
Co2_Emissions_df=Co2_Emissions[["country","year","co2","co2_growth_prct","consumption_co2","cumulative_co2","total_ghg",'ghg_per_capita', 'methane', 'methane_per_capita',
       'nitrous_oxide', 'nitrous_oxide_per_capita','primary_energy_consumption',"co2_growth_abs", 'energy_per_capita',"co2_per_capita",'population']]
Co2_Emissions_df=Co2_Emissions_df.loc[Co2_Emissions_df["year"] >=1980]
Co2_Emissions_df=Co2_Emissions_df.reset_index()
del Co2_Emissions_df["index"]

# %%
Co2_Emissions_df.groupby("country").count()
Co2_Emissions_df
# Out:
#           country  year     co2  co2_growth_prct  consumption_co2  \
# 0     Afghanistan  1980   1.757          -21.383              NaN
# 1     Afghanistan  1981   1.979           12.655              NaN
# 2     Afghanistan  1982   2.096            5.869              NaN
# 3     Afghanistan  1983   2.520           20.260              NaN
# 4     Afghanistan  1984   2.822           11.996              NaN
# ...           ...   ...     ...              ...              ...
# 9438     Zimbabwe  2014  11.962            2.838           12.760
# 9439     Zimbabwe  2015  12.163            1.685           13.010
# 9440     Zimbabwe  2016  10.807          -11.146           11.809
# 9441     Zimbabwe  2017  12.026           11.274           12.531
# 9442     Zimbabwe  2018  12.263            1.969              NaN
#
#       cumulative_co2  total_ghg  ghg_per_capita  methane  methane_per_capita  \
# 0             31.814        NaN             NaN      NaN                 NaN
# 1             33.793        NaN             NaN      NaN                 NaN
# 2             35.888        NaN             NaN      NaN                 NaN
# 3             38.409        NaN             NaN      NaN                 NaN
# 4             41.231        NaN             NaN      NaN                 NaN
# ...              ...        ...             ...      ...                 ...
# 9438         671.105      66.10           4.865    11.24               0.827
# 9439         683.268      67.49           4.885    11.87               0.859
# 9440         694.076      65.98           4.703    11.92               0.850
# 9441         706.102        NaN             NaN      NaN                 NaN
# 9442         718.364        NaN             NaN      NaN                 NaN
#
#       nitrous_oxide  nitrous_oxide_per_capita  primary_energy_consumption  \
# 0               NaN                       NaN                         NaN
# 1               NaN                       NaN                         NaN
# 2               NaN                       NaN                         NaN
# 3               NaN                       NaN                         NaN
# 4               NaN                       NaN                         NaN
# ...             ...                       ...                         ...
# 9438           6.27                     0.461                         NaN
# 9439           6.68                     0.484                         NaN
# 9440           6.55                     0.467                         NaN
# 9441            NaN                       NaN                         NaN
# 9442            NaN                       NaN                         NaN
#
#       co2_growth_abs  energy_per_capita  co2_per_capita  population
# 0             -0.478                NaN             0.0  13357000.0
# 1              0.222                NaN             0.0  13172000.0
# 2              0.116                NaN             0.0  12883000.0
# 3              0.425                NaN             0.0  12538000.0
# 4              0.302                NaN             0.0  12204000.0
# ...              ...                ...             ...         ...
# 9438           0.330                NaN             0.0  13587000.0
# 9439           0.202                NaN             0.0  13815000.0
# 9440          -1.356                NaN             0.0  14030000.0
# 9441           1.218                NaN             0.0  14237000.0
# 9442           0.237                NaN             0.0  14439000.0
#
# [9443 rows x 17 columns]

# %%
# Analyzing Co2 and GHG by country
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="World"]
Co2_Emissions_USA=Co2_Emissions_USA.reset_index(drop=True)
fig,ax=plt.subplots()
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.methane,color="green",label="CH4")
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.nitrous_oxide,color="blue",label="N2O")
plt.ylabel("CH4/N2O (Millions Per Tonnes)")
ax2=ax.twinx()
ax2.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.co2,color="red",label="CO2")
plt.ylabel("CO2(Millions Per Tonnes)")
plt.xlim(1990,2017)
plt.grid()

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_USA=Co2_Emissions_USA.reset_index(drop=True)
Co2_Emissions_USA_chart=Co2_Emissions_USA.plot.line(x='year', y='co2_growth_abs',color="blue",alpha=0.5)
plt.xlabel("Year")
plt.xlim(1990,2018)
plt.ylabel("Cumulative CO2 (Million Tonnes)")

plt.xticks(rotation=90)
plt.tight_layout()

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Brazil=Co2_Emissions_df[Co2_Emissions_df.country=="Brazil"]
Co2_Emissions_Europe=Co2_Emissions_df[Co2_Emissions_df.country=="Europe"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots()
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.co2,color="green",label="CO2")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.co2,color="red",label="CO2")
ax.plot(Co2_Emissions_Brazil.year,Co2_Emissions_Brazil.co2,color="blue",label="CO2")
ax.plot(Co2_Emissions_Europe.year,Co2_Emissions_Europe.co2,color="black",label="CO2")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.co2,color="Orange",label="CO2")

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Brazil=Co2_Emissions_df[Co2_Emissions_df.country=="Brazil"]
Co2_Emissions_Europe=Co2_Emissions_df[Co2_Emissions_df.country=="Europe"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots()
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.methane,color="green",label="CH4")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.methane,color="red",label="CH4")
ax.plot(Co2_Emissions_Brazil.year,Co2_Emissions_Brazil.methane,color="blue",label="CH4")
ax.plot(Co2_Emissions_Europe.year,Co2_Emissions_Europe.methane,color="black",label="CH4")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.methane,color="Orange",label="CH4")

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_China=Co2_Emissions_df[Co2_Emissions_df.country=="China"]
Co2_Emissions_Brazil=Co2_Emissions_df[Co2_Emissions_df.country=="Brazil"]
Co2_Emissions_Europe=Co2_Emissions_df[Co2_Emissions_df.country=="Europe"]
Co2_Emissions_India=Co2_Emissions_df[Co2_Emissions_df.country=="India"]
fig,ax=plt.subplots()
ax.plot(Co2_Emissions_USA.year,Co2_Emissions_USA.nitrous_oxide,color="green",label="N2O")
ax.plot(Co2_Emissions_China.year,Co2_Emissions_China.nitrous_oxide,color="red",label="N2O")
ax.plot(Co2_Emissions_Brazil.year,Co2_Emissions_Brazil.nitrous_oxide,color="blue",label="N2O")
ax.plot(Co2_Emissions_Europe.year,Co2_Emissions_Europe.nitrous_oxide,color="black",label="N2O")
ax.plot(Co2_Emissions_India.year,Co2_Emissions_India.nitrous_oxide,color="Orange",label="N2O")
