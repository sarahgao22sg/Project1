# %% [markdown]
# #### Import Dependencies

# %%
# define keys and dependencies: 
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Set the path to the data file

# %%
f_path=os.path.join("CO2_data.csv")
Co2_Emissions=pd.read_csv(f_path)
Co2_Emissions.head(100)
# Out:
#         country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0   Afghanistan  1949  0.015              NaN             NaN
# 1   Afghanistan  1950  0.084          475.000           0.070
# 2   Afghanistan  1951  0.092            8.696           0.007
# 3   Afghanistan  1952  0.092            0.000           0.000
# 4   Afghanistan  1953  0.106           16.000           0.015
# ..          ...   ...    ...              ...             ...
# 95       Africa  1776  0.000              NaN           0.000
# 96       Africa  1777  0.000              NaN           0.000
# 97       Africa  1778  0.000              NaN           0.000
# 98       Africa  1779  0.000              NaN           0.000
# 99       Africa  1780  0.000              NaN           0.000
#
#     consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 0               NaN        NaN              NaN             0.0
# 1               NaN        NaN              NaN             0.0
# 2               NaN        NaN              NaN             0.0
# 3               NaN        NaN              NaN             0.0
# 4               NaN        NaN              NaN             0.0
# ..              ...        ...              ...             ...
# 95              NaN        NaN              NaN             NaN
# 96              NaN        NaN              NaN             NaN
# 97              NaN        NaN              NaN             NaN
# 98              NaN        NaN              NaN             NaN
# 99              NaN        NaN              NaN             NaN
#
#     consumption_co2_per_capita  ...  ghg_per_capita  methane  \
# 0                          NaN  ...             NaN      NaN
# 1                          NaN  ...             NaN      NaN
# 2                          NaN  ...             NaN      NaN
# 3                          NaN  ...             NaN      NaN
# 4                          NaN  ...             NaN      NaN
# ..                         ...  ...             ...      ...
# 95                         NaN  ...             NaN      NaN
# 96                         NaN  ...             NaN      NaN
# 97                         NaN  ...             NaN      NaN
# 98                         NaN  ...             NaN      NaN
# 99                         NaN  ...             NaN      NaN
#
#     methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                  NaN            NaN                       NaN
# 1                  NaN            NaN                       NaN
# 2                  NaN            NaN                       NaN
# 3                  NaN            NaN                       NaN
# 4                  NaN            NaN                       NaN
# ..                 ...            ...                       ...
# 95                 NaN            NaN                       NaN
# 96                 NaN            NaN                       NaN
# 97                 NaN            NaN                       NaN
# 98                 NaN            NaN                       NaN
# 99                 NaN            NaN                       NaN
#
#     primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                          NaN                NaN             NaN   7663783.0
# 1                          NaN                NaN             NaN   7752000.0
# 2                          NaN                NaN             NaN   7840000.0
# 3                          NaN                NaN             NaN   7936000.0
# 4                          NaN                NaN             NaN   8040000.0
# ..                         ...                ...             ...         ...
# 95                         NaN                NaN             NaN         NaN
# 96                         NaN                NaN             NaN         NaN
# 97                         NaN                NaN             NaN         NaN
# 98                         NaN                NaN             NaN         NaN
# 99                         NaN                NaN             NaN  84262792.0
#
#              gdp
# 0            NaN
# 1   1.949480e+10
# 2   2.006385e+10
# 3   2.074235e+10
# 4   2.201546e+10
# ..           ...
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
#
# [100 rows x 37 columns]

# %% [markdown]
# #### List all the columns in the table

# %%
Co2_Emissions.columns
# Out:
# Index(['country', 'year', 'co2', 'co2_growth_prct', 'co2_growth_abs',
#        'consumption_co2', 'trade_co2', 'trade_co2_share', 'co2_per_capita',
#        'consumption_co2_per_capita', 'share_global_co2', 'cumulative_co2',
#        'share_global_cumulative_co2', 'co2_per_gdp', 'consumption_co2_per_gdp',
#        'co2_per_unit_energy', 'cement_co2', 'coal_co2', 'flaring_co2',
#        'gas_co2', 'oil_co2', 'cement_co2_per_capita', 'coal_co2_per_capita',
#        'flaring_co2_per_capita', 'gas_co2_per_capita', 'oil_co2_per_capita',
#        'total_ghg', 'ghg_per_capita', 'methane', 'methane_per_capita',
#        'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'primary_energy_consumption', 'energy_per_capita', 'energy_per_gdp',
#        'population', 'gdp'],
#       dtype='object')

# %% [markdown]
# #### New table that contains the columns within the area of interest analysis

# %%
Co2_Emissions.isnull().any()
Co2_Emissions.count()
Co2_Emissions_df=Co2_Emissions[["country","year","co2_growth_prct","consumption_co2","cumulative_co2","total_ghg",'ghg_per_capita', 'methane', 'methane_per_capita',
       'nitrous_oxide', 'nitrous_oxide_per_capita','primary_energy_consumption', 'energy_per_capita','population']]
Co2_Emissions_df=Co2_Emissions_df.loc[Co2_Emissions_df["year"] >=1980]
Co2_Emissions_df=Co2_Emissions_df.reset_index()
del Co2_Emissions_df["index"]
Co2_Emissions_df
# Out:
#           country  year  co2_growth_prct  consumption_co2  cumulative_co2  \
# 0     Afghanistan  1980          -21.383              NaN          31.814
# 1     Afghanistan  1981           12.655              NaN          33.793
# 2     Afghanistan  1982            5.869              NaN          35.888
# 3     Afghanistan  1983           20.260              NaN          38.409
# 4     Afghanistan  1984           11.996              NaN          41.231
# ...           ...   ...              ...              ...             ...
# 9438     Zimbabwe  2014            2.838           12.760         671.105
# 9439     Zimbabwe  2015            1.685           13.010         683.268
# 9440     Zimbabwe  2016          -11.146           11.809         694.076
# 9441     Zimbabwe  2017           11.274           12.531         706.102
# 9442     Zimbabwe  2018            1.969              NaN         718.364
#
#       total_ghg  ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0           NaN             NaN      NaN                 NaN            NaN
# 1           NaN             NaN      NaN                 NaN            NaN
# 2           NaN             NaN      NaN                 NaN            NaN
# 3           NaN             NaN      NaN                 NaN            NaN
# 4           NaN             NaN      NaN                 NaN            NaN
# ...         ...             ...      ...                 ...            ...
# 9438      66.10           4.865    11.24               0.827           6.27
# 9439      67.49           4.885    11.87               0.859           6.68
# 9440      65.98           4.703    11.92               0.850           6.55
# 9441        NaN             NaN      NaN                 NaN            NaN
# 9442        NaN             NaN      NaN                 NaN            NaN
#
#       nitrous_oxide_per_capita  primary_energy_consumption  energy_per_capita  \
# 0                          NaN                         NaN                NaN
# 1                          NaN                         NaN                NaN
# 2                          NaN                         NaN                NaN
# 3                          NaN                         NaN                NaN
# 4                          NaN                         NaN                NaN
# ...                        ...                         ...                ...
# 9438                     0.461                         NaN                NaN
# 9439                     0.484                         NaN                NaN
# 9440                     0.467                         NaN                NaN
# 9441                       NaN                         NaN                NaN
# 9442                       NaN                         NaN                NaN
#
#       population
# 0     13357000.0
# 1     13172000.0
# 2     12883000.0
# 3     12538000.0
# 4     12204000.0
# ...          ...
# 9438  13587000.0
# 9439  13815000.0
# 9440  14030000.0
# 9441  14237000.0
# 9442  14439000.0
#
# [9443 rows x 14 columns]

# %%
Co2_Emissions_USA=Co2_Emissions_df[Co2_Emissions_df.country=="United States"]
Co2_Emissions_USA=Co2_Emissions_USA.reset_index(drop=True)
